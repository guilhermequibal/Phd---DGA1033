# %%
import requests
r = requests.get('http://localhost:11434/api/tags')
print(r.json())
# You should see llama3.3:70b in the 'models' list
# Out:
# {'models': [{'name': 'llama3.3:70b', 'model': 'llama3.3:70b', 'modified_at': '2026-04-17T15:19:38.446121866-04:00', 'size': 42520413916, 'digest': 'a6eb4748fd2990ad2952b2335a95a7f952d1a06119a0aa6a2df6cd052a93a3fa', 'details': {'parent_model': '', 'format': 'gguf', 'family': 'llama', 'families': ['llama'], 'parameter_size': '70.6B', 'quantization_level': 'Q4_K_M'}}]}

# %%
import ifcopenshell
print(f'IfcOpenShell version: {ifcopenshell.version}')
# Out:
# IfcOpenShell version: 0.8.5

# %%
import llama_index.core
print(f'LlamaIndex version: {llama_index.core.__version__}')
# Out:
# LlamaIndex version: 0.14.20
